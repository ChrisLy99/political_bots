# %%
import twarc
import os
import numpy as np
import pandas as pd
import src.similarity as sim
import src.stats as stats
# %load_ext autoreload
# %autoreload 2

# %%
rt_path = os.path.join('data', 'processed', 'news')
sample = [i for i in os.listdir(rt_path) if 'rt' in i][1]

# %%
vector = 'vector.json'

# %%
vec = pd.read_json(vector, typ='series')

# %%
df = pd.read_json(os.path.join(rt_path,sample), lines=True)

# %%
df
# Out:
#                      created_at                   id               id_str  \
# 0     2021-01-26 23:52:45+00:00  1354215731831861250  1354215731831861248
# 1     2021-01-26 23:51:29+00:00  1354215416260927488  1354215416260927488
# 2     2021-01-26 23:51:13+00:00  1354215345553354809  1354215345553354752
# 3     2021-01-26 23:51:10+00:00  1354215333322776577  1354215333322776576
# 4     2021-01-26 23:50:07+00:00  1354215070998421518  1354215070998421504
# ...                         ...                  ...                  ...
# 90740 2021-01-14 23:52:10+00:00  1349866931797467136  1349866931797467136
# 90741 2021-01-14 23:51:37+00:00  1349866795046481943  1349866795046481920
# 90742 2021-01-14 23:50:56+00:00  1349866620257234945  1349866620257234944
# 90743 2021-01-14 23:50:49+00:00  1349866593371697152  1349866593371697152
# 90744 2021-01-14 23:50:46+00:00  1349866578326679553  1349866578326679552
#
#                                                full_text  truncated  \
# ...

# %%
hashtags = stats.count_features([os.path.join(rt_path,sample)])
# Out:
# data/processed/news/CNN_rts.jsonl
# vc shape (3,)

# %%
hashtags
# Out:
# FareedsTake    182
# CNNTownHall     69
# LincolnCNN      62
# dtype: int64

# %%
user_vec = hashtags.reindex(vec.index, fill_value = 0).values

# %%
sim.subsample_hashtags(vec, [os.path.join(rt_path,sample)])
# Out:
# data/processed/news/CNN_rts.jsonl
# vc shape (3,)
# COVID19                          0
# Trump                            0
# MAGA                             0
# coronavirus                      0
# Trump2020                        0
#                                 ..
# GanjaCity                        0
# Ganja                            0
# Gangleader                       0
# GangOfPutin                      0
# 100000DEADonDONALDTRUMPsWATCH    0
# Length: 27355, dtype: int64

# %%
sim.jaccard_similarity(user_vec, user_vec)
# Out:
# 1.0

# %%
v1 = np.array([1, 2, 3, 4])
v2 = np.array([4, 3, 2, 1])

# %%
type(v1)
# Out:
# numpy.ndarray

# %%
np.sum(np.minimum(v1, v2)) / np.sum(np.maximum(v1, v2))
# Out:
# 0.42857142857142855
